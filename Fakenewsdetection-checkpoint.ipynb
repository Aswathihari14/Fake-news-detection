# %%
# !pip install pandas numpy scikit-learn matplotlib

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fake = pd.read_csv("C:\\Users\\aswat\\Downloads\\archive (2)\\Fake.csv")
true = pd.read_csv("C:\\Users\\aswat\\Downloads\\archive (2)\\True.csv")

print("Fake News:", fake.shape)
print("True News:", true.shape)
# Out:
# Fake News: (23481, 4)
# True News: (21417, 4)

# %%
fake['label'] = 0   # 0 = Fake
true['label'] = 1   # 1 = Real

data = pd.concat([fake, true], axis=0)
data = data.sample(frac=1).reset_index(drop=True)  # Shuffle
data.head()
# Out:
#                                                title  \
# 0  WATCH HILARIOUSLY AWKWARD Moment Between Rick ...
# 1  CHICAGO THUG PRESIDENT PERSONALLY LEAKED CHUCK...
# 2  If elected, Clinton under pressure to appoint ...
# 3  BREAKING: ANGRY BLACK LIVES MATTER Activist AD...
# 4  Suspicious object found with body in Stockholm...
#
#                                                 text          subject  \
# 0  Franken asked Perry if he enjoyed a meeting th...  Government News
# 1  Schumer asked the President not to mention his...         politics
# 2  WASHINGTON (Reuters) - Democratic Party progre...     politicsNews
# 3  Obama inspired hate...The Latest on a man char...         politics
# 4  STOCKHOLM (Reuters) - A man was found dead on ...        worldnews
#
#                   date  label
# 0         Jan 20, 2017      0
# 1          Aug 8, 2015      0
# 2  September 29, 2016       1
# 3         May 12, 2016      0
# 4   November 16, 2017       1

# %%
X = data['text']
y = data['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
model = PassiveAggressiveClassifier(max_iter=50)
model.fit(X_train_tfidf, y_train)
# Out:
# PassiveAggressiveClassifier(max_iter=50)

# %%
y_pred = model.predict(X_test_tfidf)

print("✅ Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# ✅ Accuracy: 0.9932293986636971
#
# Confusion Matrix:
#  [[5811   38]
#  [  38 5338]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5849
#            1       0.99      0.99      0.99      5376
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
test_news = [
    "Government launches new AI program for healthcare.",
    "Celebrity says aliens live among us, shocking revelation!",
    "NASA discovers water on the moon.",
]

test_news_tfidf = vectorizer.transform(test_news)
predictions = model.predict(test_news_tfidf)

for news, label in zip(test_news, predictions):
    print(f"{news} --> {'🟢 Real News' if label==1 else '🔴 Fake News'}")
# Out:
# Government launches new AI program for healthcare. --> 🔴 Fake News
# Celebrity says aliens live among us, shocking revelation! --> 🔴 Fake News
# NASA discovers water on the moon. --> 🔴 Fake News

# %%
import pickle
pickle.dump(model, open('fake_news_model.pkl', 'wb'))
pickle.dump(vectorizer, open('vectorizer.pkl', 'wb'))

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix - Fake News Detection')
plt.show()
